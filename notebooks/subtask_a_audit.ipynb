# %%
import pandas as pd
import os

os.chdir("..")

tx = pd.read_csv("data/cleaned/transactions_clean.csv")
debts = pd.read_csv("data/cleaned/debts_clean.csv")

list(tx.columns), list(debts.columns)
# Out:
# (['transaction_id',
#   'account_id',
#   'date',
#   'amount',
#   'merchant',
#   'raw_category'],
#  ['debt_id',
#   'account_id',
#   'current_balance',
#   'interest_rate',
#   'minimum_payment'])
